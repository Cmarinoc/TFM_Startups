# %% [markdown]
# # Modelo de predicción de éxito de las startups

# %% [markdown]
# En este enlace hacen un EDA y depuración de nuestro dataset, nos puede servir como guía:
#
# https://www.kaggle.com/ajaygorkar/eda-startup-success-analysis

# %% [markdown]
# ## 1. Importación de librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %% [markdown]
# ## 2. Importación de datos

# %%
import os
current_path = os.getcwd() #get path where this notebook is saved
dataset_path =current_path+'/startups_data.csv' #get path where the startups dataset is saved

# %%
original_df=pd.read_csv(dataset_path)

# %% [markdown]
# ## 3. Análisis exploratorio inicial

# %%
original_df.head()
# Out:
#   Company_Name Dependent-Company Status year of founding  \
# 0     Company1                  Success          No Info
# 1     Company2                  Success             2011
# 2     Company3                  Success             2011
# 3     Company4                  Success             2009
# 4     Company5                  Success             2010
#
#   Age of company in years  Internet Activity Score  \
# 0                 No Info                     -1.0
# 1                       3                    125.0
# 2                       3                    455.0
# 3                       5                    -99.0
# 4                       4                    496.0
#
#      Short Description of company profile  \
# 0                      Video distribution
# 1                                     NaN
# 2                Event Data Analytics API
# 3  The most advanced analytics for mobile
# 4   The Location-Based Marketing Platform
#
# ...

# %%
len(original_df)
# Out:
# 472

# %%
len(original_df.columns)
# Out:
# 116

# %% [markdown]
# El dataset tiene 116 columnas y 472 filas

# %% [markdown]
# ### Gráficos interesantes

# %% [markdown]
# Hacer gráficos para ver cómo de desbalanceada está la variable target, gráficos de las variables categóricas, de correlaciones... todo lo que se nos ocurra que pueda interesar

# %% [markdown]
# ## 4. Procesamiento previo de los datos

# %% [markdown]
# ### Eliminación de variables no informativas

# %% [markdown]
# Eliminamos variables que no van a aportar nada al modelo (por ej. variables identificadoras):
#
# - Company name: variable identificadora
# - Short Description of company profile: descripción de la empresa, es texto libre (difícil de manejar) y su información relevante viene recogida en otras variables

# %%
df_var_elim=original_df.drop(['Company_Name','Short Description of company profile'], axis=1) #continuar

# %% [markdown]
# ### Renombrado de columnas

# %% [markdown]
# Renombramos las columnas a nombres más cortos y sin espacios para una manipulación más fácil

# %%
df_renamed=df_var_elim.rename(columns={'Dependent-Company Status': 'status', .....},inplace=True) #continuar

# %% [markdown]
# ### Replace missing values by NA

# %% [markdown]
# Detecto aquellos valores que son NA (por ejemplo, los que pone No Info, o cosas así) y los pongo como NA (después serán imputados según el tipo de variable que sean)

# %%
df_with_na=

# %% [markdown]
# ### Asignar tipo de datos correcto

# %% [markdown]
# Asignamos a los datos el tipo adecuado (aquellos que sean categóricos pero están como numéricos se cambian a categóricos, etc.)

# %%
type_data=pd.DataFrame(original_df.dtypes,columns=["Data Types"])
type_data #ver tipo de datos
# Out:
#                                                    Data Types
# Company_Name                                           object
# Dependent-Company Status                               object
# year of founding                                       object
# Age of company in years                                object
# Internet Activity Score                               float64
# Short Description of company profile                   object
# Industry of company                                    object
# Focus functions of company                             object
# Investors                                              object
# Employee Count                                        float64
# Employees count MoM change                            float64
# Has the team size grown                                object
# Est. Founding Date                                     object
# Last Funding Date                                      object
# ...

# %% [markdown]
# ### Imputar NA

# %% [markdown]
# Dependiendo del tipo de dato, imputamos de una forma u otra: para categóricas podemos imputarlo con la moda, o poner una categoría nueva que sea "nulo". Para numéricas podemos imputar con la media, o mediante árboles...

# %% [markdown]
# ### Codificación y re-agrupación de variables categóricas

# %% [markdown]
# Renombrar categorías que están mal escritas (codificación), agrupar en la misma categoría aquellas que pertenecen a la misma pero vienen escritas de diferente forma, utilizar distintos métodos para reducir número de categorías para las que tienen demasiadas categorías (por ejemplo, lumping)

# %% [markdown]
# ### Conversión de variables categóricas a numéricas

# %% [markdown]
# En el modelo no se pueden introducir variables string. Transformar a numéricas mediante transformación a dummies (función OneHotEncoder), transformación a índices (función StringIndexer), sustitución por proporción variable objetivo o por su frecuencia...
#
# También, necesario convertir variable objetivo (Success/Failure) en numérica (0/1)

# %% [markdown]
# ### Creación de nuevas variables a partir de las existentes

# %% [markdown]
# ### Feature selection

# %% [markdown]
# Aplicar técnicas de selección de variables (eliminar variables correladas, basándose en el auc, método stepwise, etc.)
#
# Aquí podemos aplicar distintos métodos selección de variables y quedarnos con varios posibles conjuntos para probar el modelo, y también podemos proibar introduciendo en el modelo todas las variables

# %% [markdown]
# ## 5. Transformaciones necesarias para poder aplicar el modelo

# %% [markdown]
# ### Assembler

# %% [markdown]
# Para aplicar el modelo en python antes es necesario aplicar VectorAssembler para que todas las variables input estén en un solo vector (features vector)

# %% [markdown]
# ### Split en train y test

# %% [markdown]
# ### Balancear variable target

# %% [markdown]
# Si está muy desbalanceada. Se pueden probaas distintas técnicas: downsampling, oversampling... en RandomForest sé que hay una opción que te permite especificar si está desbalanceada y ya hace directamente los ajustes (suele ser la mejor opción)

# %% [markdown]
# ## 6. Modelo

# %% [markdown]
# Probar distintos algoritmos, distintos conjuntos de variables, parámetros (grid search, random search...), importancia de variables, métricas de evaluación...
